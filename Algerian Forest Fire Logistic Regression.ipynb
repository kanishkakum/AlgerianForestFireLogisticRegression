# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\hp\Downloads\Algerian_forest_fires_dataset_UPDATE.csv", header=1)
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 241  6.5       fire
# 242    0   not fire
# 243  0.2   not fire
# 244  0.7   not fire
# 245  0.5  not fire

# %%
df.shape
# Out:
# (243, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# # Data cleaning

# %%
df.drop([122,123,124],inplace=True)
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.iloc[165]
# Out:
# day                 15
# month               07
# year              2012
# Temperature         34
#  RH                 45
#  Ws                 17
# Rain                 0
# FFMC              90.5
# DMC                 18
# DC                24.1
# ISI               10.9
# BUI               17.7
# FWI               14.1
# Classes        fire
# Name: 165, dtype: object

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  '],
#       dtype='object')

# %%
#Removing unnecessary spaces from column name
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes'],
#       dtype='object')

# %%
#Adding a new column region to dataframe diving the whole dataframe into two region where region bejaia is denoted by 1 and region sidi bel abbes denoted by 0
df['Region']=1
for i in range(len(df)):
    if i>=122:
        df['Region'][i]=0
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7632\2621160296.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Region'][i]=0

# %%
df['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', nan, 'not fire    '], dtype=object)

# %%
df['Classes']=df['Classes'].str.strip()

# %%
df['Classes'].uniqueque
# Out:
# <bound method Series.unique of 0      not fire
# 1      not fire
# 2      not fire
# 3      not fire
# 4      not fire
#          ...
# 238        fire
# 239    not fire
# 240    not fire
# 241    not fire
# 242    not fire
# Name: Classes, Length: 243, dtype: object>

# %%
df[df['Classes'].isnull()]
# Out:
#     day month  year Temperature  RH  Ws Rain  FFMC   DMC      DC   ISI   BUI  \
# 164  14    07  2012          37  37  18  0.2  88.9  12.9  14.6 9  12.5  10.4
#
#          FWI Classes  Region
# 164  fire        NaN       0

# %%
df['FWI'] = df.FWI.replace(r'^\s*$', np.nan, regex=True) # replacing null value with NAN

# %%
 #Let's relpace the class value with mode
modeValueRating = df['Classes'].mode()
df['Classes'].fillna(value=modeValueRating[0], inplace = True) 
#Now, let's relpace the FWI value with Median
df['FWI'].fillna(df['FWI'].median(), inplace = True) 
#relpace the blank space in DC
df['DC'] = df.DC.apply(lambda x: x.replace(' ', ''))

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#         count      mean       std  min  25%  50%  75%  max
# Region  243.0  0.502058  0.501028  0.0  0.0  1.0  1.0  1.0

# %%
#checking the datatype of columns
df.dtypes
# Out:
# day            object
# month          object
# year           object
# Temperature    object
# RH             object
# Ws             object
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# Region          int64
# dtype: object

# %%
#changing the datatype of columns
df[['Temperature','RH','Ws']]=df[['Temperature','RH','Ws']].astype(int)

# %%
df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']]=df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
# Printing all the categorical columns
cat_col = [fea for fea in df.columns if df[fea].dtype == 'O']
print('Categorical columns--',cat_col)

# Printing all the numerical columns
num_col = [fea for fea in df.columns if df[fea].dtype != 'O']
print('Numerical columns--',num_col)
# Out:
# Categorical columns-- ['day', 'month', 'year', 'Classes']
# Numerical columns-- ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Region']

# %% [markdown]
# # Checking the distribution of numerical feature

# %%
for fea in num_col:
    sns.histplot(data=df,x=fea,kde=True,bins=15,color='green')
    plt.show()

# %%
plt.figure(figsize=(15, 20))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(num_col)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[num_col[i]],shade=True, color='b',hue='Region',data=df)
    plt.xlabel(numerical_col[i])
    plt.tight_layout()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Univariate analysis for categorical feature

# %%
cat1=['month','year','Classes']
for fea in cat1:
    sns.histplot(data=df,x=fea,kde=True,bins=15,color='orange')
    plt.show()

# %%
sns.countplot(data=df,x='Classes',hue='Region')
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='count'>

# %%
for fea in num_col:
    sns.boxplot(data=df,x=fea,color='g')
    plt.title(fea)
    plt.show()

# %%
#heatmap for correlation
plt.figure(figsize = (15,10))
sns.heatmap(df[num_col].corr(), annot=True)
plt.show()

# %% [markdown]
# # Relationship between Dependent and Independent variable

# %%
plt.figure(figsize=(15,20))
plt.suptitle('Bar Plot', fontsize=20, fontweight='bold', alpha=1, y=1)

for i in range(0, len(num_col)):
    plt.subplot(5,3,i+1)
    sns.barplot(y=num_col[i], x='Classes', data=df)
    plt.tight_layout()

# %%
#relationship between tempreture and rain
plt.figure(figsize=(10,5))
sns.scatterplot(x=df['Temperature'],y=df['Rain'],data=df,hue='Region')
plt.show()

# %%
num_col
# Out:
# ['Temperature',
#  'RH',
#  'Ws',
#  'Rain',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI',
#  'Region']

# %%
plt.figure(figsize=(15,20))
plt.suptitle('Strip plot', fontsize=20, fontweight='bold', alpha=1, y=1)
num_fea_cust=[feature for feature in num_col]

for i in range(0,len(num_col)):
    plt.subplot(5,3,i+1)
    sns.stripplot(data=df, x=num_col[i], y='Classes')
    plt.tight_layout()

# %%
num_col
# Out:
# ['Temperature',
#  'RH',
#  'Ws',
#  'Rain',
#  'FFMC',
#  'DMC',
#  'DC',
#  'ISI',
#  'BUI',
#  'FWI',
#  'Region']

# %% [markdown]
# # Creating independent and dependent feature

# %%
# independent feature
X= pd.DataFrame(df, columns=['Temperature','RH','Ws','Rain','FFMC','DMC','DC','ISI','BUI','FWI','Region'])

# dependent feature
Y = pd.DataFrame(df,columns=['Classes'])

# %%
X
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Region
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5       1
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4       1
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1       1
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0       1
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5       1
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...     ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5       0
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0       0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2       0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7       0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5       0
#
# [243 rows x 11 columns]

# %%
Y
# Out:
#       Classes
# 0    not fire
# 1    not fire
# 2    not fire
# 3    not fire
# 4    not fire
# ..        ...
# 238      fire
# 239  not fire
# 240  not fire
# 241  not fire
# 242  not fire
#
# [243 rows x 1 columns]

# %% [markdown]
# # Training and test split of dataset

# %%
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Region
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5       1
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4       1
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1       1
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0       1
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5       1
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...     ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5       0
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0       0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2       0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7       0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5       0
#
# [243 rows x 11 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score ,confusion_matrix

# %%
log_reg = LogisticRegression()

# %%
# separate dataset into train and test
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=0)
print(X_train.shape, X_test.shape)
print(Y_train.shape, Y_test.shape)
# Out:
# (170, 11) (73, 11)
# (170, 1) (73, 1)

# %%
log_reg.fit(X_train,Y_train)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print(log_reg.coef_)
print(log_reg.intercept_)
# Out:
# [[ 0.37411051  0.011595    0.36184835 -0.59796393 -0.14184207  0.37111731
#   -0.04145464 -1.39321517  0.09856078 -1.89669814  0.49623941]]
# [0.13998075]

# %%
Y_pred = log_reg.predict(X_test)
